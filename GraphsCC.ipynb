# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import os

# %%
mainFolder = "C:/Users/Denis/Notebooks/CCExperimental/128_auto_calibration/"

# %%
#potato = np.load("C:/Users/Denis/Notebooks/Dottorato/CCExperimental/128_auto_calibration/RisultatiTraining/2026-04-22_04-53-43_128modi_stability_T1_duration6_rep1-10_1.npz")
potato = np.load("C:/Users/Denis/Notebooks/Dottorato/CCExperimental/128_auto_calibration/RisultatiTraining/2026-04-08_19-52-10_128modi_LossLandscape_target1_param0_3.npz")

# %%
singles = potato["arr_1"]
doubles = potato["arr_2"]

# %%
plt.plot(singles)

# %%
singles
# Out:
# array([0.47438351, 0.46214886, 0.44669062, 0.4302615 , 0.41385613,
#        0.40025209, 0.38604613, 0.37371616, 0.3638955 , 0.34982688,
#        0.33905246, 0.32483555, 0.31321819, 0.29957183, 0.28599534,
#        0.2723571 , 0.26084583, 0.24803099, 0.23601469, 0.2234565 ,
#        0.21098237, 0.19989916, 0.18966266, 0.18079485, 0.16976374,
#        0.16295654, 0.15371381, 0.14922398, 0.14336126, 0.13951965,
#        0.13770195, 0.13926425, 0.14085426, 0.14510738, 0.15130253,
#        0.15723724, 0.16737138, 0.17701974, 0.18794311, 0.19781995,
#        0.20895369, 0.22024271, 0.23231163, 0.24384146, 0.25513054,
#        0.26671953, 0.27850729, 0.28836033, 0.29998758, 0.30989662,
#        0.32134627, 0.33171418, 0.34356762, 0.3518353 , 0.36321355,
#        0.37499707, 0.38411667, 0.39397214, 0.40415768, 0.41449067,
#        0.42368223])

# %%
plt.plot(doubles)

# %%
doubles
# Out:
# array([0.59903896, 0.5726013 , 0.55078329, 0.52547918, 0.50274574,
#        0.48495567, 0.47074314, 0.45291815, 0.43554713, 0.42063555,
#        0.4048079 , 0.3910098 , 0.37375149, 0.35731022, 0.34493919,
#        0.32758223, 0.31333246, 0.29884793, 0.28645358, 0.27049615,
#        0.25787747, 0.24727435, 0.23447817, 0.22472509, 0.21632281,
#        0.2062077 , 0.20092649, 0.19746596, 0.19293168, 0.18906064,
#        0.18750536, 0.1896739 , 0.19506022, 0.19610535, 0.20240388,
#        0.20976961, 0.22004401, 0.22896331, 0.23743848, 0.24950377,
#        0.26067059, 0.27434067, 0.28679545, 0.29706899, 0.30785515,
#        0.32309106, 0.33360134, 0.34899754, 0.35836919, 0.37258112,
#        0.38333944, 0.39752634, 0.40868147, 0.42012236, 0.43170246,
#        0.44320233, 0.45395539, 0.46631667, 0.47717205, 0.48841371,
#        0.49917349])

# %%
print(np.mean(singles))
print(np.std(singles))
# Out:
# 0.15759034205707456
# 0.0006143514206343039

# %%
print(np.mean(doubles))
print(np.std(doubles))
# Out:
# 0.2135121068456397
# 0.004455716173625435

# %%
singles_deviation = singles - np.mean(singles)
singles_deviation
# Out:
# array([-1.63151223e-03, -9.08964211e-04, -1.25602942e-03,  3.63596780e-05,
#         3.39054962e-04,  1.98378545e-05, -3.99550855e-04,  3.99530204e-04,
#        -2.11392815e-04, -3.52114958e-04,  3.88806818e-05,  3.98527079e-04,
#         2.64190708e-04,  9.05653918e-04,  8.23090096e-04,  3.80890459e-04,
#         8.27877877e-04,  1.36894481e-03,  6.30702343e-04,  2.87630036e-04,
#         1.20537830e-04,  5.72345078e-05, -2.61114245e-04,  3.78899937e-05,
#        -3.67887054e-04, -2.30583298e-04, -4.06921365e-04, -2.92729680e-04,
#        -2.05170933e-04, -4.12861977e-04])

# %%
plt.plot(singles_deviation)

# %%
doubles_deviation = doubles - np.mean(doubles)
doubles_deviation
# Out:
# array([ 0.01399638,  0.00100455, -0.00170227, -0.0027447 , -0.00264148,
#        -0.00161461,  0.00751576,  0.00267274, -0.00103436, -0.00154772,
#         0.00098914,  0.00670284,  0.00179481, -0.00257009,  0.00041909,
#        -0.00039642,  0.00975867, -0.00195529, -0.00062085, -0.00235262,
#        -0.00122068, -0.00483353, -0.00500768,  0.00468648, -0.004118  ,
#        -0.00385658, -0.0046405 , -0.003834  , -0.0032309 ,  0.00038181])

# %%
plt.plot(doubles_deviation)

# %%
temp = np.load("C:/Users/Denis/Notebooks/Dottorato/CCExperimental/128_auto_calibration/RisultatiTraining/2026-06-16_05-34-24_128modi_LossLandscape_target1New_param0_duration6_32Start_1.npz")
stabilitySingles = temp["arr_1"]
stabilityDoubles = temp["arr_2"]

# %%
plt.plot(stabilitySingles)

# %%
plt.plot(stabilityDoubles)

# %%
temp = np.load("C:/Users/Denis/Notebooks/Dottorato/CCExperimental/128_auto_calibration/RisultatiTraining/2026-06-15_02-28-13_128modi_stability_T1N_duration6_rep1-10_2.npz")
stabilitySingles = temp["arr_1"]
stabilityDoubles = temp["arr_2"]
# Out:
# array([31.371201, 18.887716, 28.804689, 14.160169, 11.532816, 35.593156,
#        18.481401, 28.068804, 34.012224, 33.582025, 25.999801, 23.551609,
#        23.049601, 22.316176,  9.809424, 12.794929, 21.104836,  0.      ,
#         0.      ,  0.      ])

# %%
colorsArray = ["darkviolet", "orange", "green", "red"]

labelSize = 28

fig, axs = plt.subplots(2, 1, dpi=200, figsize=(6, 11))

fig.tight_layout()

fig.subplots_adjust( wspace=0.3, hspace=0.4)


axs[0].plot(stabilitySingles, color = "darkviolet")
axs[0].text( -0.25, 0.95,'a', transform=axs[0].transAxes, size = labelSize, fontweight='bold')
axs[0].set_title("Singles", size = labelSize, fontweight='bold', pad = 10)
axs[0].set_xlabel("Iteration", size = 24)
axs[0].set_ylabel("Loss", size = 24)
axs[0].tick_params(axis='both', which='major', labelsize=20, pad = 10)
axs[0].tick_params(axis='both', which='minor', labelsize=20)
axs[0].xaxis.set_major_locator(plt.MaxNLocator(6))
#axs[0].yaxis.set_major_locator(plt.MaxNLocator(5))


axs[1].plot(stabilityDoubles, color = "darkviolet")
axs[1].text( -0.25, 0.95,'b', transform=axs[1].transAxes, size = labelSize, fontweight='bold')
axs[1].set_title("Doubles", size = labelSize, fontweight='bold', pad = 10)
axs[1].set_xlabel("Iteration", size = 24)
axs[1].set_ylabel("Loss", size = 24)
axs[1].tick_params(axis='both', which='major', labelsize=20, pad = 10)
axs[1].tick_params(axis='both', which='minor', labelsize=20)
axs[1].xaxis.set_major_locator(plt.MaxNLocator(6))
axs[1].yaxis.set_major_locator(plt.MaxNLocator(8))
#axs[1].set_xticks([0.1, 0.01, 0.001, 0.0001])



plt.savefig('C:/Users/Denis/Notebooks/Dottorato/CCExperimental/128_auto_calibration/Images/StabilityMeasure.pdf', bbox_inches="tight")

# %%
temp = np.load(mainFolder + "TrainedModels/2026-06-15_16-51-08_128modi_LossLandscape_target1New_param0_duration6_1.npz")
lossLandscapeSingles_S1D6 = temp["arr_1"]
lossLandscapeDoubles_S1D6 = temp["arr_2"]

temp = np.load(mainFolder + "TrainedModels/2026-06-16_02-42-24_128modi_LossLandscape_target1New_param0_duration1_1.npz")
lossLandscapeSingles_S1D1 = temp["arr_1"]
lossLandscapeDoubles_S1D1 = temp["arr_2"]


temp = np.load(mainFolder + "TrainedModels/2026-06-16_05-34-24_128modi_LossLandscape_target1New_param0_duration6_32Start_1.npz")
lossLandscapeSingles_S32D6 = temp["arr_1"]
lossLandscapeDoubles_S32D6 = temp["arr_2"]

# %%
colorsArray = ["darkviolet", "orange", "green", "red"]

labelSize = 28

fig, axs = plt.subplots(2, 2, dpi=200, figsize=(12, 10))

fig.tight_layout()

fig.subplots_adjust( wspace=0.3, hspace=0.3)


axs[0,0].plot(lossLandscapeSingles_S1D6, color = colorsArray[0])
axs[0,0].plot(lossLandscapeSingles_S1D1, color = colorsArray[1])
axs[0,0].plot(lossLandscapeSingles_S32D6, color = colorsArray[2])
axs[0,0].text( -0.25, 0.95,'a', transform=axs[0,0].transAxes, size = labelSize, fontweight='bold')
axs[0,0].set_title("Singles", size = labelSize, fontweight='bold', pad = 10)
axs[0,0].set_xlabel("$V^2$", size = 24)
axs[0,0].set_ylabel("Loss", size = 24)
axs[0,0].tick_params(axis='both', which='major', labelsize=20, pad = 10)
axs[0,0].tick_params(axis='both', which='minor', labelsize=20)
axs[0,0].xaxis.set_major_locator(plt.MaxNLocator(6))
#axs[0].yaxis.set_major_locator(plt.MaxNLocator(5))
axs[0,0].xaxis.set_major_formatter(ticker.FuncFormatter( lambda x, pos: '{:g}'.format(x + 2)))


axs[0,1].plot(lossLandscapeDoubles_S1D6, color = colorsArray[0])
axs[0,1].plot(lossLandscapeDoubles_S1D1, color = colorsArray[1])
axs[0,1].plot(lossLandscapeDoubles_S32D6, color = colorsArray[2])
axs[0,1].text( -0.25, 0.95,'b', transform=axs[0,1].transAxes, size = labelSize, fontweight='bold')
axs[0,1].set_title("Doubles", size = labelSize, fontweight='bold', pad = 10)
axs[0,1].set_xlabel("$V^2$", size = 24)
axs[0,1].set_ylabel("Loss", size = 24)
axs[0,1].tick_params(axis='both', which='major', labelsize=20, pad = 10)
axs[0,1].tick_params(axis='both', which='minor', labelsize=20)
axs[0,1].xaxis.set_major_locator(plt.MaxNLocator(6))
axs[0,1].yaxis.set_major_locator(plt.MaxNLocator(8))
#axs[1].set_xticks([0.1, 0.01, 0.001, 0.0001])
axs[0,1].xaxis.set_major_formatter(ticker.FuncFormatter( lambda x, pos: '{:g}'.format(x + 2)))



axs[1,0].plot(lossLandscapeSingles_S32D6, color = colorsArray[2])
axs[1,0].text( -0.25, 0.95,'c', transform=axs[1,0].transAxes, size = labelSize, fontweight='bold')
axs[1,0].set_xlabel("$V^2$", size = 24)
axs[1,0].set_ylabel("Loss", size = 24)
axs[1,0].tick_params(axis='both', which='major', labelsize=20, pad = 10)
axs[1,0].tick_params(axis='both', which='minor', labelsize=20)
axs[1,0].xaxis.set_major_locator(plt.MaxNLocator(6))
axs[1,0].xaxis.set_major_formatter(ticker.FuncFormatter( lambda x, pos: '{:g}'.format(x + 2)))


axs[1,1].plot(lossLandscapeDoubles_S32D6, color = colorsArray[2])
axs[1,1].text( -0.25, 0.95,'d', transform=axs[1,1].transAxes, size = labelSize, fontweight='bold')
axs[1,1].set_xlabel("$V^2$", size = 24)
axs[1,1].set_ylabel("Loss", size = 24)
axs[1,1].tick_params(axis='both', which='major', labelsize=20, pad = 10)
axs[1,1].tick_params(axis='both', which='minor', labelsize=20)
axs[1,1].xaxis.set_major_locator(plt.MaxNLocator(6))
axs[1,1].xaxis.set_major_formatter(ticker.FuncFormatter( lambda x, pos: '{:g}'.format(x + 2)))


plt.savefig(mainFolder + "Images/LossLandscape.pdf", bbox_inches="tight")

# %%
path  = 'C:\\Users\\Denis\\Notebooks\\CCExperimental\\128_auto_calibration\\matriciFixed'
file_name = 'Unitary_mat.npz'
folder_temp = 'DATI_2026_05_29_misure_multiple\\all_32'

data_temp = os.path.join(path, folder_temp, file_name)
U_temp = np.load(data_temp)
All32Matrix= U_temp['U']

# %%
path  = 'C:\\Users\\Denis\\Notebooks\\CCExperimental\\128_auto_calibration\\matriciFixed'
file_name = 'Unitary_mat.npz'
folder_temp = 'target_10_new'

data_temp = os.path.join(path, folder_temp, file_name)
U_temp = np.load(data_temp)
Target1Matrix_start = U_temp['U']

# %%
path  = 'C:\\Users\\Denis\\Notebooks\\CCExperimental\\128_auto_calibration\\matriciFixed'
file_name = 'Unitary_mat.npz'
folder_temp = 'DATI_2026_05_31_128modi_training_target10N_3PairsPre_32Start_1'

data_temp = os.path.join(path, folder_temp, file_name)
U_temp = np.load(data_temp)
Target1Matrix_trained = U_temp['U']

# %%
plt.imshow(np.real(Target1Matrix_start))

# %%
plt.imshow(np.real(Target1Matrix_trained))

# %%
plt.imshow(np.real(All32Matrix))

# %%
colorsArray = ["darkviolet", "orange", "green", "red"]

labelSize = 28

fig, axs = plt.subplots(1, 3, dpi=200, figsize=(10, 10))

fig.tight_layout()

fig.subplots_adjust( wspace=0.3, hspace=0.4)


#axs[0].text( -0.25, 0.95,'a', transform=axs[0].transAxes, size = labelSize, fontweight='bold')
#axs[0].set_title("Singles", size = labelSize, fontweight='bold', pad = 10)
#axs[0].set_xlabel("Iteration", size = 24)
#axs[0].set_ylabel("Loss", size = 24)
#axs[0].tick_params(axis='both', which='major', labelsize=20, pad = 10)
#axs[0].tick_params(axis='both', which='minor', labelsize=20)
#axs[0].xaxis.set_major_locator(plt.MaxNLocator(6))
#axs[0].yaxis.set_major_locator(plt.MaxNLocator(5))


#axs[1].plot(stabilityDoubles, color = "darkviolet")
#axs[1].text( -0.25, 0.95,'b', transform=axs[1].transAxes, size = labelSize, fontweight='bold')
#axs[1].set_title("Doubles", size = labelSize, fontweight='bold', pad = 10)
#axs[1].set_xlabel("Iteration", size = 24)
#axs[1].set_ylabel("Loss", size = 24)
#axs[1].tick_params(axis='both', which='major', labelsize=20, pad = 10)
#axs[1].tick_params(axis='both', which='minor', labelsize=20)
#axs[1].xaxis.set_major_locator(plt.MaxNLocator(6))
#axs[1].yaxis.set_major_locator(plt.MaxNLocator(8))
#axs[1].set_xticks([0.1, 0.01, 0.001, 0.0001])

axs[0].imshow(np.real(Target1Matrix_start))


axs[1].imshow(np.real(Target1Matrix_trained))


axs[2].imshow(np.real(All32Matrix))

#plt.savefig('C:/Users/Denis/Notebooks/Dottorato/CCExperimental/128_auto_calibration/Images/StabilityMeasure.pdf', bbox_inches="tight")

# %%
colorsArray = ["darkviolet", "orange", "green", "red"]

labelSize = 28

fig, axs = plt.subplots(1, 3, dpi=200, figsize=(10, 10))

fig.tight_layout()

fig.subplots_adjust( wspace=0.3, hspace=0.4)


#axs[0].text( -0.25, 0.95,'a', transform=axs[0].transAxes, size = labelSize, fontweight='bold')
#axs[0].set_title("Singles", size = labelSize, fontweight='bold', pad = 10)
#axs[0].set_xlabel("Iteration", size = 24)
#axs[0].set_ylabel("Loss", size = 24)
#axs[0].tick_params(axis='both', which='major', labelsize=20, pad = 10)
#axs[0].tick_params(axis='both', which='minor', labelsize=20)
#axs[0].xaxis.set_major_locator(plt.MaxNLocator(6))
#axs[0].yaxis.set_major_locator(plt.MaxNLocator(5))


#axs[1].plot(stabilityDoubles, color = "darkviolet")
#axs[1].text( -0.25, 0.95,'b', transform=axs[1].transAxes, size = labelSize, fontweight='bold')
#axs[1].set_title("Doubles", size = labelSize, fontweight='bold', pad = 10)
#axs[1].set_xlabel("Iteration", size = 24)
#axs[1].set_ylabel("Loss", size = 24)
#axs[1].tick_params(axis='both', which='major', labelsize=20, pad = 10)
#axs[1].tick_params(axis='both', which='minor', labelsize=20)
#axs[1].xaxis.set_major_locator(plt.MaxNLocator(6))
#axs[1].yaxis.set_major_locator(plt.MaxNLocator(8))
#axs[1].set_xticks([0.1, 0.01, 0.001, 0.0001])

axs[0].imshow(np.imag(Target1Matrix_start))


axs[1].imshow(np.imag(Target1Matrix_trained))


axs[2].imshow(np.imag(All32Matrix))

#plt.savefig('C:/Users/Denis/Notebooks/Dottorato/CCExperimental/128_auto_calibration/Images/StabilityMeasure.pdf', bbox_inches="tight")

# %%
Target1Matrix_start
# Out:
# array([[7.53665048e-02+0.j        , 4.41240362e-18+0.07206002j,
#         3.77771218e-02+0.j        , 6.74013234e-02+0.j        ],
#        [4.16683226e-02+0.j        , 3.06638363e-02+0.j        ,
#         3.21143442e-02+0.j        , 6.97839187e-02+0.j        ],
#        [6.95560580e-02+0.j        , 8.51327543e-02+0.j        ,
#         7.82034191e-02+0.j        , 1.92922067e-02+0.j        ],
#        [7.90188563e-02+0.j        , 1.42815973e-01+0.j        ,
#         6.44352305e-02+0.j        , 7.61660732e-02+0.j        ],
#        [9.33235502e-02+0.j        , 1.25728087e-01+0.j        ,
#         4.95264246e-02+0.j        , 4.88399949e-02+0.j        ],
#        [1.03670793e-01+0.j        , 1.18469198e-01+0.j        ,
#         2.18435162e-02+0.j        , 4.48293897e-02+0.j        ],
#        [0.00000000e+00+0.j        , 0.00000000e+00+0.j        ,
#         0.00000000e+00+0.j        , 0.00000000e+00+0.j        ],
#        [0.00000000e+00+0.j        , 0.00000000e+00+0.j        ,
# ...

# %%
All32Matrix
# Out:
# array([[5.16937320e-02+0.j        , 1.00379565e-17+0.16393227j,
#         3.84519314e-02+0.j        , 1.37747181e-02+0.j        ],
#        [6.99021352e-02+0.j        , 1.98845699e-02+0.j        ,
#         1.14377458e-02+0.j        , 4.41625199e-02+0.j        ],
#        [7.95799772e-02+0.j        , 7.84822636e-02+0.j        ,
#         8.35047165e-02+0.j        , 9.59623684e-02+0.j        ],
#        [9.38850539e-02+0.j        , 1.00306642e-01+0.j        ,
#         1.60431573e-01+0.j        , 8.33959027e-02+0.j        ],
#        [3.03901436e-02+0.j        , 9.88153401e-02+0.j        ,
#         1.04226125e-01+0.j        , 1.41662939e-01+0.j        ],
#        [2.89799042e-02+0.j        , 3.37116032e-02+0.j        ,
#         3.06531174e-02+0.j        , 9.23520245e-02+0.j        ],
#        [0.00000000e+00+0.j        , 0.00000000e+00+0.j        ,
#         0.00000000e+00+0.j        , 0.00000000e+00+0.j        ],
#        [0.00000000e+00+0.j        , 0.00000000e+00+0.j        ,
# ...

# %%
path  = 'C:\\Users\\Denis\\Notebooks\\CCExperimental\\128_auto_calibration\\matrici'
file_name = 'Unitary_mat.npz'
folder_temp = 'DATI_2026_03_27_target'

data_temp = os.path.join(path, folder_temp, file_name)
U_temp = np.load(data_temp)
potato = U_temp['U']

# %%
potato
# Out:
# array([[2.38667429e-02+0.j        , 1.15577322e-17+0.18875209j,
#         7.63300649e-02+0.j        , 7.24584708e-02+0.j        ],
#        [9.41869865e-02+0.j        , 2.76560496e-02+0.j        ,
#         1.22473231e-01+0.j        , 1.28112771e-01+0.j        ],
#        [4.55153843e-02+0.j        , 2.98629642e-02+0.j        ,
#         1.16355593e-01+0.j        , 5.85359419e-02+0.j        ],
#        [6.32177254e-02+0.j        , 1.45380728e-01+0.j        ,
#         2.12798039e-01+0.j        , 8.73458530e-02+0.j        ],
#        [1.16463177e-01+0.j        , 9.49971594e-02+0.j        ,
#         6.51381171e-02+0.j        , 8.33591992e-02+0.j        ],
#        [4.01718332e-02+0.j        , 2.73156027e-02+0.j        ,
#         9.12713616e-02+0.j        , 1.04700794e-01+0.j        ],
#        [0.00000000e+00+0.j        , 0.00000000e+00+0.j        ,
#         0.00000000e+00+0.j        , 0.00000000e+00+0.j        ],
#        [0.00000000e+00+0.j        , 0.00000000e+00+0.j        ,
# ...

# %%
baseFolder = "C:\\Users\\Denis\\Notebooks\\CCExperimental\\128_auto_calibration\\TrainedModels\\"
#chosenFile = "2026-06-12_19-20-15_128modi_training_target11_3PairsPre_32Start_17ResComp_1"
chosenFile = "2026-05-31_14-49-36_128modi_training_target11N_3PairsPre_32Start_1"


potato = np.load(baseFolder + chosenFile + "_intermediate.npz")
lossSingles = potato["arr_1"]

potato = np.load(baseFolder + chosenFile + "_resultF1.npz")
lossDoubles = potato["arr_1"]

potato = np.load(baseFolder + chosenFile + "_resultF2.npz")
lossDoubles = np.append(lossDoubles, potato["arr_1"])

potato = np.load(baseFolder + chosenFile + "_resultF3.npz")
lossDoubles = np.append(lossDoubles, potato["arr_1"])

# %%
lossSingles
# Out:
# array([0.87976127, 0.87327448, 0.8497424 , 0.84720854, 0.8419941 ,
#        0.82363164, 0.80406047, 0.79381469, 0.78338372, 0.7813266 ,
#        0.74596798, 0.73372405, 0.6957854 , 0.68888356, 0.69289202,
#        0.68665163, 0.6706877 , 0.66569412, 0.66557568, 0.6446322 ,
#        0.64470382, 0.62943541, 0.62739161, 0.61971008, 0.62127463,
#        0.60863188, 0.59252983, 0.58880278, 0.55476126, 0.55452728,
#        0.54780127, 0.51718053, 0.48619204, 0.48471432, 0.48297903,
#        0.46514241, 0.46528448, 0.46265327, 0.46294475, 0.46341032,
#        0.44221577, 0.44222813, 0.42639542, 0.42316044, 0.42234033,
#        0.41207718, 0.40441341, 0.40400759, 0.39997541, 0.39381099,
#        0.38879648, 0.37898691, 0.37605099, 0.35874476, 0.35736451,
#        0.33889074, 0.33992367, 0.33975839, 0.32944093, 0.33236828,
#        0.33093192, 0.33231422, 0.33223686, 0.3212145 , 0.31781867,
#        0.31239472, 0.30825417, 0.30160727, 0.30427669, 0.30299545,
# ...

# %%
lossDoubles
# Out:
# array([0.58993803, 0.52112808, 0.50839468, 0.51429491, 0.51450232,
#        0.51667371, 0.51636166, 0.5140625 , 0.5064144 , 0.5188532 ,
#        0.5167061 , 0.50115653, 0.49854432, 0.49183678, 0.48081318,
#        0.48805392, 0.49831661, 0.48360647, 0.50362249, 0.46891081,
#        0.46072349, 0.46250185, 0.46117603, 0.45290474, 0.46918681,
#        0.47597044, 0.46903019, 0.45662993, 0.44009138, 0.43638881,
#        0.44251427, 0.42914236, 0.44004182, 0.43450337, 0.43600249,
#        0.44865568, 0.42933468, 0.43767325, 0.4363981 , 0.43540743,
#        0.43892149, 0.43418009, 0.42914742, 0.43431833, 0.4281851 ,
#        0.42937446, 0.42936079, 0.42371161, 0.43440601, 0.43220991,
#        0.44014547, 0.43628685, 0.44114726, 0.44075354, 0.43400393,
#        0.43622962, 0.42452006, 0.44032213, 0.41192168, 0.41989234,
#        0.42520144, 0.41770706, 0.42423769, 0.42305324, 0.41937562,
#        0.40768162, 0.40024189, 0.41321999, 0.42166379, 0.4299689 ,
# ...

# %%
plt.plot(lossSingles)

# %%
plt.plot(lossDoubles)
